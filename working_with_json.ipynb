# %%
import pandas as pd

# %% [markdown]
# # Working with JSON

# %%
data_local = pd.read_json('train.json')
data_local.head()

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')

# %%
exchange_data = pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
exchange_data.head()

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='',
    database='world'
)

# %%
query = "SELECT * FROM countrylanguage"
df_sql = pd.read_sql_query(query, connection)

# %%
df_sql.head()
